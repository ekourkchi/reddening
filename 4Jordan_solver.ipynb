# %%
import numpy as np
import matplotlib.pyplot as plt
from redTools import *

def f(x):
    return -7.*x**3+(2.*x**2)*np.log10(x)+15-x

# %%
x = np.linspace(0.01, 2,20)

plt.plot(x, f(x))
plt.plot([0,2],[0,0], 'k:')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0,0.5,'f(x)')

# %%
x0, N = solver(f, 0.01, 2, threshold=0.0001) 
print N, x0, f(x0)
# Out:
# 54 1.2617102230510846 3.763595213257531e-09

# %%
x = np.linspace(0.01, 2,15)

plt.plot(x, f(x), '.')
plt.plot([0,2],[0,0], 'k:')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.plot([x0,x0], [-10,10], 'g--')

# %%
def f(x):
    return (-7*x**3)+(2*x**2*np.log(x))+15

x = np.linspace(0, 3, 100000)
y = x
y1 = f(x)

#x = np.linspace(0, 12, 200)
#y = np.sin(x)
#y1 = np.cos(x)

plt.plot(x, y)
plt.plot(x, y1)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

plt.xlim([1.24,1.32])
plt.ylim([-1,2])

idx = np.argwhere(np.diff(np.sign(y1 - y))).flatten()


plt.plot(x[idx], y1[idx], 'ro')
x[idx], y1[idx]
# Out:
# /home/ehsan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ehsan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in multiply
#   This is separate from the ipykernel package so we can avoid doing imports until
# (array([0.        , 1.27519275]), array([       nan, 1.27532493]))
